# %% [markdown]
# # Trace Count v20: query-first RoPE, counts 1–30
#
# Controlled setting: 256 Shakespeare characters, a three-character query before
# the data, RoPE, paired nonthinking/thinking models, and count range 1–30.
# Number representation is **atomic: one dedicated token for every integer 1..30**. The full v10-compatible causal suite runs after the phase analysis.
#
# Dense scientific snapshots are stored every 100 steps, full optimizer/RNG recovery
# state every 500 steps, and five snapshots are packed into each shard. This avoids
# thousands of Drive files and avoids raw per-token attention exports.

# %% [markdown]
# ## 1. Mount Google Drive

# %%
from pathlib import Path

DRIVE_RESULTS_ROOT = Path(
    "/content/drive/MyDrive/Colab_Notebooks/CoT_Counting/"
    "Synthetic_CoT_NiaH_Count/colab_results"
)
DRIVE_READY = False
if Path("/content").exists():
    from google.colab import drive
    if not Path("/content/drive/MyDrive").exists():
        drive.mount("/content/drive")
    DRIVE_RESULTS_ROOT.mkdir(parents=True, exist_ok=True)
    DRIVE_READY = True
    print("Drive ready:", DRIVE_RESULTS_ROOT)
else:
    print("Local runtime: Drive mount skipped")
# Out:
# Mounted at /content/drive
# Drive ready: /content/drive/MyDrive/Colab_Notebooks/CoT_Counting/Synthetic_CoT_NiaH_Count/colab_results

# %% [markdown]
# ## 2. Clone/update the repo on local Colab storage

# %%
import os
import signal
import subprocess
import sys
import time
from pathlib import Path

assert DRIVE_READY, "Run the Drive cell first"
REPO_URL = "https://github.com/Twist-Shan/Synthetic_CoT_NiaH_Count.git"
preferred = Path("/content/Synthetic_CoT_NiaH_Count")
candidates = [Path.cwd(), *Path.cwd().parents, preferred]
repo = next((path.resolve() for path in candidates if (path / "pyproject.toml").exists()), None)
if repo is None:
    subprocess.run(["git", "clone", REPO_URL, str(preferred)], check=True)
    repo = preferred
elif (repo / ".git").exists():
    subprocess.run(["git", "-C", str(repo), "pull", "--ff-only"], check=True)
assert (repo / "src" / "synthetic_counting_v20").is_dir(), f"synthetic_counting_v20 is absent from {repo}"
os.chdir(repo)

scientific_probe = subprocess.run(
    [sys.executable, "-c", "import numpy,pandas,scipy,matplotlib,seaborn"],
    capture_output=True,
    text=True,
)
if scientific_probe.returncode:
    print(scientific_probe.stderr[-2000:])
    subprocess.run(
        [
            sys.executable, "-m", "pip", "install", "-q", "--no-cache-dir",
            "--force-reinstall", "numpy==1.26.4", "pandas==2.2.3",
            "scipy==1.13.1", "matplotlib==3.8.4", "seaborn==0.13.2",
        ],
        check=True,
    )
    if Path("/content").exists():
        os.kill(os.getpid(), signal.SIGKILL)
    raise RuntimeError("Scientific ABI repaired. Reconnect and rerun all cells.")
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "--no-deps", "-e", "."], check=True)
src_root = str(repo / "src")
if src_root not in sys.path:
    sys.path.insert(0, src_root)
os.environ["PYTHONPATH"] = src_root + os.pathsep + os.environ.get("PYTHONPATH", "")

import numpy as np
import pandas as pd
import torch
import synthetic_counting_v20
from IPython.display import Image, display

def run_streaming(command):
    import codecs
    command = [str(part) for part in command]
    print("$", " ".join(command), flush=True)
    process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, bufsize=0)
    assert process.stdout is not None
    decoder = codecs.getincrementaldecoder("utf-8")(errors="replace")
    while True:
        chunk = os.read(process.stdout.fileno(), 4096)
        if not chunk:
            break
        print(decoder.decode(chunk), end="", flush=True)
    print(decoder.decode(b"", final=True), end="", flush=True)
    returncode = process.wait()
    if returncode:
        raise subprocess.CalledProcessError(returncode, command)

print({
    "repo": str(repo),
    "package": str(Path(synthetic_counting_v20.__file__).resolve()),
    "torch": torch.__version__,
    "cuda": torch.cuda.is_available(),
    "gpu": torch.cuda.get_device_name(0) if torch.cuda.is_available() else None,
})
# Out:
# {'repo': '/content/Synthetic_CoT_NiaH_Count', 'package': '/content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/__init__.py', 'torch': '2.11.0+cu128', 'cuda': True, 'gpu': 'NVIDIA A100-SXM4-40GB'}

# %% [markdown]
# ## 3. Auditable experiment settings

# %%
VERSION = "v20"
PRESET = "main"                 # change to debug for a short end-to-end check
SEED = 1234
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
COUNT_MAX_THRESHOLD = 30
NEEDLE_POOL_SIZE = 100
NEEDLE_POOL_FREQUENCY_THRESHOLD = 0.12
TASK_OCCURRENCE_RATIO = 1.0
MAX_TRAIN_STEPS = 10_000
MAX_STEPS_FOR_LANGUAGE_PRED = 1_500
CHECKPOINT_EVERY_STEPS = 100     # model-only scientific snapshot
RECOVERY_EVERY_STEPS = 500       # full optimizer/RNG recovery state
SNAPSHOT_SHARD_EVERY_STEPS = 500 # five 100-step snapshots per file
EVAL_EVERY_STEPS = 500
AR_EVAL_EVERY_STEPS = 1_000
AR_EXAMPLES_PER_COUNT = 2
PERMUTATION_EXAMPLES_PER_COUNT = 1  # each expands to all six query orders
EVAL_EXAMPLES_PER_COUNT = 10
FINAL_EXAMPLES_PER_COUNT = 50
PHASE_SELECTION_EXAMPLES_PER_COUNT = 2
PHASE_REPORT_EXAMPLES_PER_COUNT = 1
if PRESET == "debug":
    COUNT_MAX_THRESHOLD = 4
    MAX_TRAIN_STEPS = 6
    MAX_STEPS_FOR_LANGUAGE_PRED = 6
    CHECKPOINT_EVERY_STEPS = 3
    RECOVERY_EVERY_STEPS = 3
    SNAPSHOT_SHARD_EVERY_STEPS = 3
    EVAL_EVERY_STEPS = 3
    AR_EVAL_EVERY_STEPS = 3
    AR_EXAMPLES_PER_COUNT = 1
    EVAL_EXAMPLES_PER_COUNT = 2
    FINAL_EXAMPLES_PER_COUNT = 2
    PHASE_SELECTION_EXAMPLES_PER_COUNT = 1
OUT_ROOT = "runs/synthetic_counting_v20"
RUN_NAME = None
SKIP_COMPLETED = True
AUTO_DISCONNECT = True
DISCONNECT_DELAY_SECONDS = 10
# The run folder itself is the Drive result folder; no second checkpoint copy.
CHECKPOINT_SYNC_ROOT = DRIVE_RESULTS_ROOT

from synthetic_counting_v20.config import preset_config
PLANNED_CONFIG = preset_config(
    PRESET,
    seed=SEED,
    device=DEVICE,
    count_max_threshold=COUNT_MAX_THRESHOLD,
    needle_pool_size=NEEDLE_POOL_SIZE,
    needle_pool_frequency_threshold=NEEDLE_POOL_FREQUENCY_THRESHOLD,
    task_occurrence_ratio=TASK_OCCURRENCE_RATIO,
    train_steps=MAX_TRAIN_STEPS,
    max_steps_for_language_pred=MAX_STEPS_FOR_LANGUAGE_PRED,
    checkpoint_every=CHECKPOINT_EVERY_STEPS,
    recovery_every=RECOVERY_EVERY_STEPS,
    snapshot_shard_every=SNAPSHOT_SHARD_EVERY_STEPS,
    eval_every=EVAL_EVERY_STEPS,
    ar_eval_every=AR_EVAL_EVERY_STEPS,
    ar_examples_per_count=AR_EXAMPLES_PER_COUNT,
    permutation_examples_per_count=PERMUTATION_EXAMPLES_PER_COUNT,
    eval_examples_per_count=EVAL_EXAMPLES_PER_COUNT,
    final_examples_per_count=FINAL_EXAMPLES_PER_COUNT,
    phase_head_selection_examples_per_count=PHASE_SELECTION_EXAMPLES_PER_COUNT,
    phase_examples_per_count=PHASE_REPORT_EXAMPLES_PER_COUNT,
)
print(PLANNED_CONFIG.to_dict())
print({
    "sequence_layout": "<BOS> query[5] data[256] output",
    "number_representation": PLANNED_CONFIG.count_tokenization,
    "max_render_len": PLANNED_CONFIG.max_render_len,
    "dense_snapshots_per_model": len(range(0, MAX_TRAIN_STEPS + 1, CHECKPOINT_EVERY_STEPS)),
    "snapshot_files_per_model": MAX_TRAIN_STEPS // SNAPSHOT_SHARD_EVERY_STEPS + 1,
    "recovery_policy": "rolling latest plus pinned objective boundary and final",
})
# Out:
# {'version': 'v20', 'preset': 'main', 'seed': 1234, 'seq_len': 256, 'needle_set_size': 3, 'needle_pool_size': 100, 'needle_pool_frequency_threshold': 0.12, 'needle_pool_frequency_bins': 20, 'needle_pool_seed': None, 'count_max_threshold': 30, 'task_occurrence_ratio': 1.0, 'corpus_train_fraction': 0.8, 'corpus_validation_fraction': 0.1, 'candidate_filter_max_attempts': 100000, 'shuffle_needle_set_order': True, 'position_encodings': ['rope'], 'enabled_model_variants': ['rope/nonthinking', 'rope/thinking'], 'train_steps': 10000, 'batch_size': 128, 'lr': 0.0003, 'weight_decay': 0.01, 'adam_beta1': 0.9, 'adam_beta2': 0.999, 'warmup_steps': 500, 'grad_clip': 1.0, 'precision': 'bf16', 'log_every': 50, 'eval_every': 500, 'ar_eval_every': 1000, 'checkpoint_every': 100, 'recovery_every': 500, 'snapshot_shard_every': 500, 'snapshot_dtype': 'float16', 'eval_examples_per_count': 10, 'final_examples_per_count': 50, 'ar_examples_per_count': 2, 'permutation_examples_per_count': 1, 'max_steps_for_language_pred': 1500, 'final_count_loss_weight': 1.0, 'cot_trace_loss_weight': 1.0, 'n_layer': 4, 'n_head': 4, 'n_embd': 256, 'n_inner': 1024, 'n_positions': 384, 'max_relative_distance': 256, 'rpe_max_update': False, 'rope_base': 10000.0, 'attention_examples_per_count': 10, 'state_train_examples_per_count': 20, 'state_eval_examples_per_count': 10, 'phase_examples_per_count': 1, 'phase_head_selection_examples_per_count': 2, 'phase_cloud_steps': (0, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 5000, 7000, 10000), 'analysis_batch_size': 64, 'device': 'cuda', 'noise_source': 'shakespeare_char', 'task_type': 'target_character_set', 'loss_scope': 'all_sequence', 'query_layout': 'query_first', 'count_tokenization': 'atomic', 'use_sdpa': True, 'count_max': 30, 'count_max_alias': 'read-only alias of count_max_threshold', 'effective_needle_pool_seed': 21234, 'corpus_test_fraction': 0.09999999999999995, 'training_objective': 'teacher-forced weighted next-token cross-entropy over every non-padding token through step 1500; from step 1501, task-output targets only, starting inclusively at <Ans> for nonthinking and <Think> for thinking', 'training_loss_schedule': 'steps 1-1500: all_sequence; steps 1501-10000: task_output', 'task_output_scope': {'nonthinking': '<Ans> through <EOS>, inclusive', 'thinking': '<Think> through <EOS>, inclusive'}, 'task_occurrence_ratio_definition': 'example-level probability of formatting a training corpus window as a counting task', 'sequence_layout': 'query_first', 'sequence_templates': {'nonthinking': '<BOS> query[5] data[256] <Ans> number <EOS>', 'thinking': '<BOS> query[5] data[256] <Think> (number marker)*n </Think> <Ans> number <EOS>'}, 'checkpoint_policy': {'analysis_snapshot_every': 100, 'optimizer_recovery_every': 500, 'snapshot_shard_every': 500, 'snapshot_dtype': 'float16'}}
# {'sequence_layout': '<BOS> query[5] data[256] output', 'number_representation': 'atomic', 'max_render_len': 327, 'dense_snapshots_per_model': 101, 'snapshot_files_per_model': 21, 'recovery_policy': 'rolling latest plus pinned objective boundary and final'}

# %% [markdown]
# ## 4. Prepare fixed data, pool, and evaluation manifests

# %%
base_cmd = [
    sys.executable, "-u", "-m", "synthetic_counting_v20.run_v20",
    "--preset", PRESET,
    "--device", DEVICE,
    "--seed", str(SEED),
    "--count-max-threshold", str(COUNT_MAX_THRESHOLD),
    "--needle-pool-size", str(NEEDLE_POOL_SIZE),
    "--needle-pool-frequency-threshold", str(NEEDLE_POOL_FREQUENCY_THRESHOLD),
    "--task-occurrence-ratio", str(TASK_OCCURRENCE_RATIO),
    "--train-steps", str(MAX_TRAIN_STEPS),
    "--max-steps-for-language-pred", str(MAX_STEPS_FOR_LANGUAGE_PRED),
    "--checkpoint-every", str(CHECKPOINT_EVERY_STEPS),
    "--recovery-every", str(RECOVERY_EVERY_STEPS),
    "--snapshot-shard-every", str(SNAPSHOT_SHARD_EVERY_STEPS),
    "--eval-every", str(EVAL_EVERY_STEPS),
    "--ar-eval-every", str(AR_EVAL_EVERY_STEPS),
    "--ar-examples-per-count", str(AR_EXAMPLES_PER_COUNT),
    "--permutation-examples-per-count", str(PERMUTATION_EXAMPLES_PER_COUNT),
    "--eval-examples-per-count", str(EVAL_EXAMPLES_PER_COUNT),
    "--final-examples-per-count", str(FINAL_EXAMPLES_PER_COUNT),
    "--phase-head-selection-examples-per-count", str(PHASE_SELECTION_EXAMPLES_PER_COUNT),
    "--phase-examples-per-count", str(PHASE_REPORT_EXAMPLES_PER_COUNT),
    "--out-root", OUT_ROOT,
    "--checkpoint-sync-root", str(CHECKPOINT_SYNC_ROOT),
    "--model-variant", "rope/nonthinking",
    "--model-variant", "rope/thinking",
]
if RUN_NAME is not None:
    base_cmd += ["--run-name", RUN_NAME]
if SKIP_COMPLETED:
    base_cmd.append("--skip-completed")
run_streaming([*base_cmd, "--stage", "prepare"])

from synthetic_counting_v20.config import default_run_name
RUN_DIR = Path(OUT_ROOT) / (RUN_NAME or default_run_name(PLANNED_CONFIG))
DRIVE_RUN_DIR = CHECKPOINT_SYNC_ROOT / RUN_DIR.name
print("RUN_DIR:", RUN_DIR.resolve())
print("DRIVE_RUN_DIR:", DRIVE_RUN_DIR)
# Out:
# $ /usr/bin/python3 -u -m synthetic_counting_v20.run_v20 --preset main --device cuda --seed 1234 --count-max-threshold 30 --needle-pool-size 100 --needle-pool-frequency-threshold 0.12 --task-occurrence-ratio 1.0 --train-steps 10000 --max-steps-for-language-pred 1500 --checkpoint-every 100 --recovery-every 500 --snapshot-shard-every 500 --eval-every 500 --ar-eval-every 1000 --ar-examples-per-count 2 --permutation-examples-per-count 1 --eval-examples-per-count 10 --final-examples-per-count 50 --phase-head-selection-examples-per-count 2 --phase-examples-per-count 1 --out-root runs/synthetic_counting_v20 --checkpoint-sync-root /content/drive/MyDrive/Colab_Notebooks/CoT_Counting/Synthetic_CoT_NiaH_Count/colab_results --model-variant rope/nonthinking --model-variant rope/thinking --skip-completed --stage prepare
# [v20] stage=prepare
# [timing:start] scope=pipeline block=prepare
# [timing:done] scope=pipeline block=prepare seconds=2.63 status=complete
# [timing:start] scope=pipeline block=drive_sync_prepare
# [timing:done] scope=pipeline block=drive_sync_prepare seconds=0.23 status=complete
# FINAL_RUN_DIR=/content/Synthetic_CoT_NiaH_Count/runs/synthetic_counting_v20/v20_main_L256_pool100x3_pf0p12_count1-30_taskr1_wd0p01_fcw1_cotw1_langsteps1500_steps10000_snap100_recover500_evaln300_rope-nt-rope-t_atomic_query-first_allseq-taskout_seed1234
# RUN_DIR: /content/Synthetic_CoT_NiaH_Count/runs/synthetic_counting_v20/v20_main_L256_pool100x3_pf0p12_count1-30_taskr1_wd0p01_fcw1_cotw1_langsteps1500_steps10000_snap100_recover500_evaln300_rope-nt-rope-t_atomic_query-first_allseq-taskout_seed1234
# DRIVE_RUN_DIR: /content/drive/MyDrive/Colab_Notebooks/CoT_Counting/Synthetic_CoT_NiaH_Count/colab_results/v20_main_L256_pool100x3_pf0p12_count1-30_taskr1_wd0p01_fcw1_cotw1_langsteps1500_steps10000_snap100_recover500_evaln300_rope-nt-rope-t_atomic_query-first_allseq-taskout_seed1234

# %% [markdown]
# ## 5. Train the paired models (live progress is streamed)

# %%
training_started = time.perf_counter()
run_streaming([*base_cmd, "--stage", "train"])
print(f"Training block: {time.perf_counter() - training_started:.1f} seconds")
# Out:
# $ /usr/bin/python3 -u -m synthetic_counting_v20.run_v20 --preset main --device cuda --seed 1234 --count-max-threshold 30 --needle-pool-size 100 --needle-pool-frequency-threshold 0.12 --task-occurrence-ratio 1.0 --train-steps 10000 --max-steps-for-language-pred 1500 --checkpoint-every 100 --recovery-every 500 --snapshot-shard-every 500 --eval-every 500 --ar-eval-every 1000 --ar-examples-per-count 2 --permutation-examples-per-count 1 --eval-examples-per-count 10 --final-examples-per-count 50 --phase-head-selection-examples-per-count 2 --phase-examples-per-count 1 --out-root runs/synthetic_counting_v20 --checkpoint-sync-root /content/drive/MyDrive/Colab_Notebooks/CoT_Counting/Synthetic_CoT_NiaH_Count/colab_results --model-variant rope/nonthinking --model-variant rope/thinking --skip-completed --stage train
# [timing:start] scope=pipeline block=drive_restore
# [timing:done] scope=pipeline block=drive_restore seconds=0.01 status=complete
# [v20] stage=train
# [timing:start] scope=pipeline block=train
# [train] rope/nonthinking
# [timing:start] scope=training variant=rope/nonthinking step=0 block=checkpoint_write
# [timing:start] scope=training variant=rope/nonthinking step=0 block=checkpoint_serialize
# [timing:done] scope=training variant=rope/nonthinking step=0 block=checkpoint_serialize seconds=0.03 status=complete
# [timing:start] scope=training variant=rope/nonthinking step=0 block=checkpoint_drive_sync
# [timing:done] scope=training variant=rope/nonthinking step=0 block=checkpoint_drive_sync seconds=0.07 status=complete
# [timing:done] scope=training variant=rope/nonthinking step=0 block=checkpoint_write seconds=0.12 status=complete
# [timing:start] scope=training variant=rope/nonthinking step=0 block=periodic_teacher_forced_evaluation
# [timing:done] scope=training variant=rope/nonthinking step=0 block=periodic_teacher_forced_evaluation seconds=5.66 status=complete
# v20 rope/nonthinking:   0%|          | 0/10000 [00:01<?, ?it/s, loss=4.6794, task=1.00][train] rope/nonthinking step=1/10000 loss=4.6794 lr=6.000e-07 grad_norm=8.750 task_ratio=1.00
# v20 rope/nonthinking:   0%|          | 49/10000 [00:06<12:43, 13.03it/s, loss=3.5749, task=1.00] [train] rope/nonthinking step=50/10000 loss=3.5749 lr=3.000e-05 grad_norm=1.748 task_ratio=1.00
# v20 rope/nonthinking:   1%|          | 99/10000 [00:11<12:49, 12.87it/s, loss=2.9290, task=1.00][train] rope/nonthinking step=100/10000 loss=2.9290 lr=6.000e-05 grad_norm=1.299 task_ratio=1.00
# v20 rope/nonthinking:   1%|▏         | 149/10000 [00:16<12:52, 12.76it/s, loss=2.6156, task=1.00][train] rope/nonthinking step=150/10000 loss=2.6156 lr=9.000e-05 grad_norm=1.793 task_ratio=1.00
# v20 rope/nonthinking:   2%|▏         | 199/10000 [00:21<12:46, 12.79it/s, loss=2.4228, task=1.00][train] rope/nonthinking step=200/10000 loss=2.4228 lr=1.200e-04 grad_norm=3.403 task_ratio=1.00
# v20 rope/nonthinking:   2%|▏         | 249/10000 [00:26<12:44, 12.76it/s, loss=2.1955, task=1.00][train] rope/nonthinking step=250/10000 loss=2.1955 lr=1.500e-04 grad_norm=2.759 task_ratio=1.00
# v20 rope/nonthinking:   3%|▎         | 299/10000 [00:31<12:37, 12.80it/s, loss=2.0223, task=1.00][train] rope/nonthinking step=300/10000 loss=2.0223 lr=1.800e-04 grad_norm=3.369 task_ratio=1.00
# v20 rope/nonthinking:   3%|▎         | 349/10000 [00:36<12:29, 12.87it/s, loss=1.9147, task=1.00][train] rope/nonthinking step=350/10000 loss=1.9147 lr=2.100e-04 grad_norm=3.110 task_ratio=1.00
# v20 rope/nonthinking:   4%|▍         | 399/10000 [00:41<13:16, 12.06it/s, loss=1.7601, task=1.00][train] rope/nonthinking step=400/10000 loss=1.7601 lr=2.400e-04 grad_norm=2.117 task_ratio=1.00
# v20 rope/nonthinking:   4%|▍         | 449/10000 [00:46<12:21, 12.89it/s, loss=1.6601, task=1.00][train] rope/nonthinking step=450/10000 loss=1.6601 lr=2.700e-04 grad_norm=1.984 task_ratio=1.00
# v20 rope/nonthinking:   5%|▍         | 499/10000 [00:51<12:13, 12.95it/s, loss=1.5935, task=1.00][train] rope/nonthinking step=500/10000 loss=1.5935 lr=3.000e-04 grad_norm=1.840 task_ratio=1.00
# [timing:done] scope=training variant=rope/nonthinking step=500 block=optimizer_interval seconds=39.53 status=complete
# [timing:start] scope=training variant=rope/nonthinking step=500 block=periodic_teacher_forced_evaluation
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/nonthinking step=500 block=periodic_teacher_forced_evaluation seconds=5.07 status=complete
# [timing:start] scope=training variant=rope/nonthinking step=500 block=checkpoint_write
# [timing:start] scope=training variant=rope/nonthinking step=500 block=checkpoint_serialize
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/nonthinking step=500 block=checkpoint_serialize seconds=0.06 status=complete
# [timing:start] scope=training variant=rope/nonthinking step=500 block=checkpoint_drive_sync
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/nonthinking step=500 block=checkpoint_drive_sync seconds=0.16 status=complete
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/nonthinking step=500 block=checkpoint_write seconds=0.23 status=complete
# v20 rope/nonthinking:   5%|▌         | 549/10000 [01:02<12:15, 12.85it/s, loss=1.5209, task=1.00]  [train] rope/nonthinking step=550/10000 loss=1.5209 lr=3.000e-04 grad_norm=1.559 task_ratio=1.00
# v20 rope/nonthinking:   6%|▌         | 599/10000 [01:07<12:18, 12.72it/s, loss=1.4713, task=1.00][train] rope/nonthinking step=600/10000 loss=1.4713 lr=2.999e-04 grad_norm=1.595 task_ratio=1.00
# v20 rope/nonthinking:   6%|▋         | 649/10000 [01:12<12:24, 12.56it/s, loss=1.4263, task=1.00][train] rope/nonthinking step=650/10000 loss=1.4263 lr=2.998e-04 grad_norm=1.598 task_ratio=1.00
# v20 rope/nonthinking:   7%|▋         | 699/10000 [01:17<12:07, 12.79it/s, loss=1.3802, task=1.00][train] rope/nonthinking step=700/10000 loss=1.3802 lr=2.997e-04 grad_norm=1.335 task_ratio=1.00
# v20 rope/nonthinking:   7%|▋         | 749/10000 [01:22<12:05, 12.75it/s, loss=1.3389, task=1.00][train] rope/nonthinking step=750/10000 loss=1.3389 lr=2.995e-04 grad_norm=1.323 task_ratio=1.00
# v20 rope/nonthinking:   8%|▊         | 799/10000 [01:27<11:55, 12.86it/s, loss=1.3226, task=1.00][train] rope/nonthinking step=800/10000 loss=1.3226 lr=2.993e-04 grad_norm=1.417 task_ratio=1.00
# v20 rope/nonthinking:   8%|▊         | 849/10000 [01:32<11:52, 12.84it/s, loss=1.3105, task=1.00][train] rope/nonthinking step=850/10000 loss=1.3105 lr=2.990e-04 grad_norm=1.277 task_ratio=1.00
# v20 rope/nonthinking:   9%|▉         | 899/10000 [01:37<11:47, 12.86it/s, loss=1.2879, task=1.00][train] rope/nonthinking step=900/10000 loss=1.2879 lr=2.987e-04 grad_norm=1.182 task_ratio=1.00
# v20 rope/nonthinking:   9%|▉         | 949/10000 [01:42<11:49, 12.76it/s, loss=1.2489, task=1.00][train] rope/nonthinking step=950/10000 loss=1.2489 lr=2.983e-04 grad_norm=1.184 task_ratio=1.00
# v20 rope/nonthinking:  10%|▉         | 999/10000 [01:47<11:36, 12.92it/s, loss=1.2232, task=1.00][train] rope/nonthinking step=1000/10000 loss=1.2232 lr=2.980e-04 grad_norm=1.126 task_ratio=1.00
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/nonthinking step=1000 block=optimizer_interval seconds=39.04 status=complete
# [timing:start] scope=training variant=rope/nonthinking step=1000 block=periodic_teacher_forced_evaluation
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/nonthinking step=1000 block=periodic_teacher_forced_evaluation seconds=5.02 status=complete
# [timing:start] scope=training variant=rope/nonthinking step=1000 block=periodic_autoregressive_evaluation
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/nonthinking step=1000 block=periodic_autoregressive_evaluation seconds=0.26 status=complete
# [timing:start] scope=training variant=rope/nonthinking step=1000 block=checkpoint_write
# [timing:start] scope=training variant=rope/nonthinking step=1000 block=checkpoint_serialize
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/nonthinking step=1000 block=checkpoint_serialize seconds=0.06 status=complete
# [timing:start] scope=training variant=rope/nonthinking step=1000 block=checkpoint_drive_sync
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/nonthinking step=1000 block=checkpoint_drive_sync seconds=0.16 status=complete
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/nonthinking step=
task_ratio=1.00
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=9500 block=optimizer_interval seconds=80.63 status=complete
# [timing:start] scope=training variant=rope/thinking step=9500 block=periodic_teacher_forced_evaluation
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=9500 block=periodic_teacher_forced_evaluation seconds=6.40 status=complete
# [timing:start] scope=training variant=rope/thinking step=9500 block=checkpoint_write
# [timing:start] scope=training variant=rope/thinking step=9500 block=checkpoint_serialize
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=9500 block=checkpoint_serialize seconds=0.06 status=complete
# [timing:start] scope=training variant=rope/thinking step=9500 block=checkpoint_drive_sync
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=9500 block=checkpoint_drive_sync seconds=0.16 status=complete
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=9500 block=checkpoint_write seconds=0.24 status=complete
# v20 rope/thinking:  95%|█████████▌| 9549/10000 [32:32<01:13,  6.10it/s, loss=0.0126, task=1.00][train] rope/thinking step=9550/10000 loss=0.0126 lr=1.658e-06 grad_norm=1.227 task_ratio=1.00
# v20 rope/thinking:  96%|█████████▌| 9599/10000 [32:42<01:04,  6.25it/s, loss=0.0070, task=1.00][train] rope/thinking step=9600/10000 loss=0.0070 lr=1.310e-06 grad_norm=1.045 task_ratio=1.00
# v20 rope/thinking:  96%|█████████▋| 9649/10000 [32:51<00:55,  6.29it/s, loss=0.0072, task=1.00][train] rope/thinking step=9650/10000 loss=0.0072 lr=1.004e-06 grad_norm=0.626 task_ratio=1.00
# v20 rope/thinking:  97%|█████████▋| 9699/10000 [33:01<00:48,  6.21it/s, loss=0.0081, task=1.00][train] rope/thinking step=9700/10000 loss=0.0081 lr=7.376e-07 grad_norm=0.920 task_ratio=1.00
# v20 rope/thinking:  97%|█████████▋| 9749/10000 [33:10<00:40,  6.18it/s, loss=0.0091, task=1.00][train] rope/thinking step=9750/10000 loss=0.0091 lr=5.123e-07 grad_norm=0.880 task_ratio=1.00
# v20 rope/thinking:  98%|█████████▊| 9799/10000 [33:20<00:32,  6.22it/s, loss=0.0051, task=1.00][train] rope/thinking step=9800/10000 loss=0.0051 lr=3.280e-07 grad_norm=0.730 task_ratio=1.00
# v20 rope/thinking:  98%|█████████▊| 9849/10000 [33:29<00:24,  6.25it/s, loss=0.0072, task=1.00][train] rope/thinking step=9850/10000 loss=0.0072 lr=1.845e-07 grad_norm=0.903 task_ratio=1.00
# v20 rope/thinking:  99%|█████████▉| 9899/10000 [33:39<00:16,  6.29it/s, loss=0.0049, task=1.00][train] rope/thinking step=9900/10000 loss=0.0049 lr=8.201e-08 grad_norm=0.476 task_ratio=1.00
# v20 rope/thinking:  99%|█████████▉| 9949/10000 [33:48<00:08,  6.00it/s, loss=0.0086, task=1.00][train] rope/thinking step=9950/10000 loss=0.0086 lr=2.050e-08 grad_norm=0.835 task_ratio=1.00
# v20 rope/thinking: 100%|█████████▉| 9999/10000 [33:58<00:00,  6.19it/s, loss=0.0063, task=1.00][train] rope/thinking step=10000/10000 loss=0.0063 lr=0.000e+00 grad_norm=0.825 task_ratio=1.00
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=optimizer_interval seconds=80.87 status=complete
# [timing:start] scope=training variant=rope/thinking step=10000 block=periodic_teacher_forced_evaluation
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=periodic_teacher_forced_evaluation seconds=6.36 status=complete
# [timing:start] scope=training variant=rope/thinking step=10000 block=periodic_autoregressive_evaluation
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=periodic_autoregressive_evaluation seconds=1.20 status=complete
# [timing:start] scope=training variant=rope/thinking step=10000 block=checkpoint_write
# [timing:start] scope=training variant=rope/thinking step=10000 block=checkpoint_serialize
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=checkpoint_serialize seconds=0.06 status=complete
# [timing:start] scope=training variant=rope/thinking step=10000 block=checkpoint_drive_sync
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=checkpoint_drive_sync seconds=0.16 status=complete
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=checkpoint_write seconds=0.24 status=complete
# v20 rope/thinking: 100%|██████████| 10000/10000 [34:06<00:00,  4.89it/s, loss=0.0063, task=1.00]
# [timing:start] scope=training variant=rope/thinking step=10000 block=checkpoint_write_final
# [timing:start] scope=training variant=rope/thinking step=10000 block=checkpoint_final_serialize
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=checkpoint_final_serialize seconds=0.06 status=complete
# [timing:start] scope=training variant=rope/thinking step=10000 block=checkpoint_final_drive_sync
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=checkpoint_final_drive_sync seconds=0.10 status=complete
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=checkpoint_write_final seconds=0.18 status=complete
# [timing:start] scope=training variant=rope/thinking step=10000 block=final_test
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=final_test seconds=39.68 status=complete
# [timing:start] scope=training variant=rope/thinking step=10000 block=prefix_permutation_evaluation
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=training variant=rope/thinking step=10000 block=prefix_permutation_evaluation seconds=2.37 status=complete
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=pipeline block=train seconds=3279.72 status=complete
# [timing:start] scope=pipeline block=drive_sync_train
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=pipeline block=drive_sync_train seconds=19.41 status=complete
# FINAL_RUN_DIR=/content/Synthetic_CoT_NiaH_Count/runs/synthetic_counting_v20/v20_main_L256_pool100x3_pf0p12_count1-30_taskr1_wd0p01_fcw1_cotw1_langsteps1500_steps10000_snap100_recover500_evaln300_rope-nt-rope-t_atomic_query-first_allseq-taskout_seed1234
# Training block: 3303.9 seconds

# %% [markdown]
# ## 6. Dense phase, geometry, and causal analyses

# %%
analysis_started = time.perf_counter()
analysis_stages = "phase,causal,plots" if PRESET == "main" else "phase,plots"
run_streaming([*base_cmd, "--stage", analysis_stages])
print(f"Analysis block: {time.perf_counter() - analysis_started:.1f} seconds")

expected = [
    RUN_DIR / "analysis" / "phase_transition" / "manifest.json",
    RUN_DIR / "analysis" / "phase_transition" / "interactive_manifold_3d.html",
    RUN_DIR / "analysis" / "phase_transition" / "tables" / "phase_transition_candidates.csv",
    RUN_DIR / "tables" / "training_token_exposure_by_k.csv",
    RUN_DIR / "figures" / "dense_fixed_head_emergence.png",
    RUN_DIR / "figures" / "dense_marker_manifold_emergence.png",
    RUN_DIR / "figures" / "milestone_local_head_causality.png",
]
if VERSION == "v20" and PRESET == "main":
    expected.append(RUN_DIR / "analysis" / "v10_port" / "manifest.json")
missing = [str(path) for path in expected if not path.exists()]
assert not missing, "Missing required outputs: " + str(missing)
for path in expected:
    print(path.relative_to(RUN_DIR), path.stat().st_size)
# Out:
# $ /usr/bin/python3 -u -m synthetic_counting_v20.run_v20 --preset main --device cuda --seed 1234 --count-max-threshold 30 --needle-pool-size 100 --needle-pool-frequency-threshold 0.12 --task-occurrence-ratio 1.0 --train-steps 10000 --max-steps-for-language-pred 1500 --checkpoint-every 100 --recovery-every 500 --snapshot-shard-every 500 --eval-every 500 --ar-eval-every 1000 --ar-examples-per-count 2 --permutation-examples-per-count 1 --eval-examples-per-count 10 --final-examples-per-count 50 --phase-head-selection-examples-per-count 2 --phase-examples-per-count 1 --out-root runs/synthetic_counting_v20 --checkpoint-sync-root /content/drive/MyDrive/Colab_Notebooks/CoT_Counting/Synthetic_CoT_NiaH_Count/colab_results --model-variant rope/nonthinking --model-variant rope/thinking --skip-completed --stage phase,causal,plots
# [timing:start] scope=pipeline block=drive_restore
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=pipeline block=drive_restore seconds=0.09 status=complete
# [v20] stage=phase
# [timing:start] scope=pipeline block=phase
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=pipeline block=phase seconds=91.34 status=complete
# [timing:start] scope=pipeline block=drive_sync_phase
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=pipeline block=drive_sync_phase seconds=7.05 status=complete
# [v20] stage=causal
# [timing:start] scope=pipeline block=causal
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/v10_port_analysis.py:511: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   frame = pd.concat(parts, ignore_index=True)
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=pipeline block=causal seconds=3.91 status=failed
# [timing:start] scope=pipeline block=drive_failure_sync_causal
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=pipeline block=drive_failure_sync_causal seconds=22.20 status=complete
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/run_v20.py", line 5, in <module>
#     main()
#   File "/content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/cli.py", line 105, in main
#     run_v20_pipeline(
#   File "/content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/pipeline.py", line 270, in run_v20_pipeline
#     run_v10_port_analysis(run_dir, device=cfg.device)
#   File "/content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/v10_port_analysis.py", line 1557, in run_v10_port_analysis
#     geometry, coordinates, centroids = run_geometry(ctx, options)
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/v10_port_analysis.py", line 914, in run_geometry
#     archive = np.load(part)
#               ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py", line 455, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Synthetic_CoT_NiaH_Count/runs/synthetic_counting_v20/v20_main_L256_pool100x3_pf0p12_count1-30_taskr1_wd0p01_fcw1_cotw1_langsteps1500_steps10000_snap100_recover500_evaln300_rope-nt-rope-t_atomic_query-first_allseq-taskout_seed1234/analysis/checkpoint_dynamics/parts/rope_nonthinking_step_010000/heldout_states.npz'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_884/692471542.py in <cell line: 0>()
#       1 analysis_started = time.perf_counter()
#       2 analysis_stages = "phase,causal,plots" if PRESET == "main" else "phase,plots"
# ----> 3 run_streaming([*base_cmd, "--stage", analysis_stages])
#       4 print(f"Analysis block: {time.perf_counter() - analysis_started:.1f} seconds")
#       5
#
# /tmp/ipykernel_884/4107877765.py in run_streaming(command)
#      64     returncode = process.wait()
#      65     if returncode:
# ---> 66         raise subprocess.CalledProcessError(returncode, command)
#      67
#      68 print({
#
# CalledProcessError: Command '['/usr/bin/python3', '-u', '-m', 'synthetic_counting_v20.run_v20', '--preset', 'main', '--device', 'cuda', '--seed', '1234', '--count-max-threshold', '30', '--needle-pool-size', '100', '--needle-pool-frequency-threshold', '0.12', '--task-occurrence-ratio', '1.0', '--train-steps', '10000', '--max-steps-for-language-pred', '1500', '--checkpoint-every', '100', '--recovery-every', '500', '--snapshot-shard-every', '500', '--eval-every', '500', '--ar-eval-every', '1000', '--ar-examples-per-count', '2', '--permutation-examples-per-count', '1', '--eval-examples-per-count', '10', '--final-examples-per-count', '50', '--phase-head-selection-examples-per-count', '2', '--phase-examples-per-count', '1', '--out-root', 'runs/synthetic_counting_v20', '--checkpoint-sync-root', '/content/drive/MyDrive/Colab_Notebooks/CoT_Counting/Synthetic_CoT_NiaH_Count/colab_results', '--model-variant', 'rope/nonthinking', '--model-variant', 'rope/thinking', '--skip-completed', '--stage', 'phase,causal,plots']' returned non-zero exit status 1.

# %% [markdown]
# ## 7. Inspect the main diagnostics

# %%
for filename in (
    "training_token_exposure_by_k.png",
    "dense_phase_behavior_by_count.png",
    "dense_fixed_head_emergence.png",
    "dense_marker_manifold_emergence.png",
    "milestone_local_head_causality.png",
):
    path = RUN_DIR / "figures" / filename
    if path.exists():
        display(Image(filename=str(path)))
display(pd.read_csv(RUN_DIR / "analysis" / "phase_transition" / "tables" / "fixed_head_rankings.csv").head(12))
display(pd.read_csv(RUN_DIR / "analysis" / "phase_transition" / "tables" / "milestone_local_head_causality.csv"))
# Out:
#                   role  rank  layer  head  selection_score  \
# 0   targeted_retrieval     1      4     2         0.628067
# 1   targeted_retrieval     2      4     1         0.561707
# 2   targeted_retrieval     3      4     3         0.110819
# 3   targeted_retrieval     4      4     0         0.066495
# 4   targeted_retrieval     5      3     1         0.012127
# 5   targeted_retrieval     6      2     3         0.009116
# 6   targeted_retrieval     7      2     0         0.007989
# 7   targeted_retrieval     8      1     2         0.006913
# 8   targeted_retrieval     9      1     0         0.005917
# 9   targeted_retrieval    10      1     1         0.005831
# 10  targeted_retrieval    11      1     3         0.005470
# 11  targeted_retrieval    12      3     2         0.002537
#
#            selection_split  selection_checkpoint
# 0   heldout_head_selection                 10000
# 1   heldout_head_selection                 10000
# 2   heldout_head_selection                 10000
# 3   heldout_head_selection                 10000
# 4   heldout_head_selection                 10000
# 5   heldout_head_selection                 10000
# 6   heldout_head_selection                 10000
# 7   heldout_head_selection                 10000
# 8   heldout_head_selection                 10000
# 9   heldout_head_selection                 10000
# 10  heldout_head_selection                 10000
# 11  heldout_head_selection                 10000
#      step                role             intervention  layer  head  accuracy  \
# 0       0  targeted_retrieval                 baseline    NaN   NaN  0.000000
# 1       0  targeted_retrieval          fixed_head_zero    4.0   2.0  0.000000
# 2       0  targeted_retrieval  same_layer_control_zero    4.0   1.0  0.000000
# 3       0    marker_successor                 baseline    NaN   NaN  0.023656
# 4       0    marker_successor          fixed_head_zero    2.0   3.0  0.021505
# ..    ...                 ...                      ...    ...   ...       ...
# 61  10000  targeted_retrieval          fixed_head_zero    4.0   2.0  0.933333
# 62  10000  targeted_retrieval  same_layer_control_zero    4.0   1.0  0.913978
# 63  10000    marker_successor                 baseline    NaN   NaN  0.997849
# 64  10000    marker_successor          fixed_head_zero    2.0   3.0  0.537634
# 65  10000    marker_successor  same_layer_control_zero    2.0   0.0  0.978495
#
#       margin  accuracy_change_from_baseline  margin_change_from_baseline  \
# 0  -0.780918                       0.000000                     0.000000
# 1  -0.781213                       0.000000                    -0.000295
# 2  -0.773820                       0.000000                     0.007098
# 3  -1.007682                       0.000000                     0.000000
# 4  -1.025359                      -0.002151                    -0.017677
# ..       ...                            ...                          ...
# 61  6.028686                      -0.062366                    -3.514511
# 62  5.568258                      -0.081720                    -3.974938
# 63  9.438595                       0.000000                     0.000000
# 64 -0.743169                      -0.460215                   -10.181765
# 65  7.468683                      -0.019355                    -1.969913
#
#                                   intervention_scope
# 0   selected head slice only at role query positions
# 1   selected head slice only at role query positions
# 2   selected head slice only at role query positions
# 3   selected head slice only at role query positions
# 4   selected head slice only at role query positions
# ..                                               ...
# 61  selected head slice only at role query positions
# 62  selected head slice only at role query positions
# 63  selected head slice only at role query positions
# 64  selected head slice only at role query positions
# 65  selected head slice only at role query positions
#
# [66 rows x 10 columns]

# %% [markdown]
# ## 8. Verify Drive persistence and optionally disconnect

# %%
# Re-running plots also triggers the pipeline's incremental final Drive sync.
run_streaming([*base_cmd, "--stage", "plots"])
required_drive_files = [
    DRIVE_RUN_DIR / "config.json",
    DRIVE_RUN_DIR / "manifest.json",
    DRIVE_RUN_DIR / "analysis" / "phase_transition" / "manifest.json",
    DRIVE_RUN_DIR / "checkpoints" / "rope" / "thinking" / "snapshot_index.csv",
    DRIVE_RUN_DIR / "checkpoints" / "rope" / "thinking" / "final" / "checkpoint.pt",
]
missing = [str(path) for path in required_drive_files if not path.exists()]
assert not missing, "Drive persistence check failed: " + str(missing)
print("Drive persistence verified:", DRIVE_RUN_DIR)

if AUTO_DISCONNECT and Path("/content").exists():
    print(f"Disconnecting in {DISCONNECT_DELAY_SECONDS}s after successful persistence check...")
    time.sleep(DISCONNECT_DELAY_SECONDS)
    try:
        from google.colab import runtime
        runtime.unassign()
    except Exception:
        os.kill(os.getpid(), 9)
# Out:
# $ /usr/bin/python3 -u -m synthetic_counting_v20.run_v20 --preset main --device cuda --seed 1234 --count-max-threshold 30 --needle-pool-size 100 --needle-pool-frequency-threshold 0.12 --task-occurrence-ratio 1.0 --train-steps 10000 --max-steps-for-language-pred 1500 --checkpoint-every 100 --recovery-every 500 --snapshot-shard-every 500 --eval-every 500 --ar-eval-every 1000 --ar-examples-per-count 2 --permutation-examples-per-count 1 --eval-examples-per-count 10 --final-examples-per-count 50 --phase-head-selection-examples-per-count 2 --phase-examples-per-count 1 --out-root runs/synthetic_counting_v20 --checkpoint-sync-root /content/drive/MyDrive/Colab_Notebooks/CoT_Counting/Synthetic_CoT_NiaH_Count/colab_results --model-variant rope/nonthinking --model-variant rope/thinking --skip-completed --stage plots
# [timing:start] scope=pipeline block=drive_restore
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=pipeline block=drive_restore seconds=0.08 status=complete
# [v20] stage=plots
# [timing:start] scope=pipeline block=plots
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=pipeline block=plots seconds=2.60 status=complete
# [timing:start] scope=pipeline block=drive_sync_plots
# /content/Synthetic_CoT_NiaH_Count/src/synthetic_counting_v20/timing.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat((existing, frame), ignore_index=True)
# [timing:done] scope=pipeline block=drive_sync_plots seconds=7.62 status=complete
# FINAL_RUN_DIR=/content/Synthetic_CoT_NiaH_Count/runs/synthetic_counting_v20/v20_main_L256_pool100x3_pf0p12_count1-30_taskr1_wd0p01_fcw1_cotw1_langsteps1500_steps10000_snap100_recover500_evaln300_rope-nt-rope-t_atomic_query-first_allseq-taskout_seed1234
# Drive persistence verified: /content/drive/MyDrive/Colab_Notebooks/CoT_Counting/Synthetic_CoT_NiaH_Count/colab_results/v20_main_L256_pool100x3_pf0p12_count1-30_taskr1_wd0p01_fcw1_cotw1_langsteps1500_steps10000_snap100_recover500_evaln300_rope-nt-rope-t_atomic_query-first_allseq-taskout_seed1234
# Disconnecting in 10s after successful persistence check...
